# %%
import pandas as pd

# %%
df = pd.read_csv('sentiment_pbt_Feb26.csv')

# %%
df.head()
# Out:
#    Unnamed: 0 company_name overall_scores balance_scores benefit_scores  \
# 0           0       Google   width: 100%;   width: 100%;   width: 100%;
# 1           1       Google   width: 100%;   width: 100%;   width: 100%;
# 2           2       Google   width: 100%;   width: 100%;   width: 100%;
# 3           3       Google   width: 100%;   width: 100%;   width: 100%;
# 4           4       Google   width: 100%;   width: 100%;   width: 100%;
#
#   security_scores management_scores culture_scores  former_current  lead  \
# 0    width: 100%;      width: 100%;   width: 100%;             1.0     0
# 1    width: 100%;      width: 100%;   width: 100%;             1.0     0
# 2    width: 100%;      width: 100%;   width: 100%;             1.0     0
# 3    width: 100%;      width: 100%;   width: 100%;             1.0     0
# 4    width: 100%;      width: 100%;   width: 100%;             1.0     0
#
#        ...       other_states  wa  \
# 0      ...                  1   0
# ...

# %%
df.groupby('company_name').final_pbt_sc.mean()
# Out:
# company_name
# Adobe                0.425971
# Airbnb               0.394000
# Apple                0.384343
# Boeing               0.390675
# Cisco                0.355089
# Dell                 0.321573
# Expedia              0.224867
# Google               0.340324
# IBM                  0.200017
# Indeed               0.378298
# Intel                0.412966
# JLL                  0.254017
# KPMG                 0.253223
# Kaiser Permanente    0.465540
# Microsoft            0.392964
# NOKIA                0.384591
# Netflix              0.407536
# Nordstrom            0.282991
# Oracle               0.204458
# Qualcomm             0.263159
# Redfin               0.286315
# Salesforce           0.491458
# T-mobile             0.448775
# Tableau             -0.000167
# Tesla                0.260840
# Texas Instrument     0.443759
# Twitter              0.349042
# Uber                 0.201444
# Name: final_pbt_sc, dtype: float64
